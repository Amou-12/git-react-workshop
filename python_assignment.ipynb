# %% [markdown]
# <a href="https://colab.research.google.com/github/Amou-12/git-react-workshop/blob/main/python_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Excercise 1
#Python Basics



def capitalize_words(input_string):
    ## Write your code here
    words = input_string.split()
    capitalized_words = [word.capitalize() for word in words]
    result = " ".join(capitalized_words)
    return result
    ### Your code ends here


#Exercise 2
#control flow

# This is the function that you need to populate with your code
def fizz_buzz(start, end, divisor):
    ## Write your code here
    result = []
    for i in range(start, end + 1):
        if i % divisor == 0:
            result.append("Fizz")
        else:
            result.append(str(i))
    return result
    ### Your code ends here



  #Excercise 3
  # Data Structures

  # This is the function that you need to populate with your code
def unique_elements(nested_lists):
  result = set()
  for sublist in nested_lists:
        for item in sublist:
            result.add(item)
  return result



#Excersice 4
#Functions and Critical Thinking

# This is the function that you need to populate with your code
def word_frequency(input_string):
  # Convert to lowercase to make it case-insensitive
  input_string = input_string.lower()

    # Remove punctuation using str.translate
  input_string = input_string.translate(str.maketrans("", "", string.punctuation))

    # Split the string into words
  words = input_string.split()

    # Create a dictionary to count word frequencies
  freq = {}
  for word in words:
      freq[word] = freq.get(word, 0) + 1

  return freq
